# %%
def test_fun(a,b,c):
    return a,b,c
a,b,c=test_fun(1,2,3)
# Out:
# 1

# %%
A=[1,2,3,4,5]
print(A[1:1000])
# Out:
# [2, 3, 4, 5]

# %%
binary=b"\x00"
type(binary)
print(binary.hex())
# Out:
# 00
