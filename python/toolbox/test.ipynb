# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 A=123
# ----> 2 A.split()
#
# AttributeError: 'int' object has no attribute 'split'
