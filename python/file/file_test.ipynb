# %% [markdown]
# ### 读取一个二进制文件并读取前8字节

# %%
with open("map.bin", 'rb') as file:
    pre_8_bytes = file.read(8)
    print(pre_8_bytes)
    print(type(pre_8_bytes))#字节串类型
    print(pre_8_bytes[0:2])
# Out:
# b's\x02\x00\x00\x92\t\x00\x00'
# <class 'bytes'>
# b's\x02'

# %% [markdown]
# ### 将一个字节串转换成int
# pre_8_bytes[0]返回的是对应字节对应的整数
# pre_8_byte[0:1]则是返回一个字节序列，
# 需要注意的是int.from_bytes()接收的是一个字节序列

# %%
pre_8_bytes=b's\x02\x00\x00\x92\t\x00\x00'
print(pre_8_bytes[0:1])
print(int.from_bytes(pre_8_bytes[0:1],"little"))
print(int.from_bytes(pre_8_bytes[2],"little"))
# Out:
# b's'
# 115
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       2 print(pre_8_bytes[0:1])
#       3 print(int.from_bytes(pre_8_bytes[0:1],"little"))
# ----> 4 print(int.from_bytes(pre_8_bytes[2],"little"))
#
# TypeError: cannot convert 'int' object to bytes

# %% [markdown]
# ### 从bin文件的第9个字节(地址8) 开始读取特定个字节

# %%
with open("map.bin", 'rb') as file:
    json_length = int.from_bytes(pre_8_bytes[0:4], byteorder='little')  #return 627
    file.seek(8)  # seek 是0基索引，第9字节为索引8
    data_bytes = file.read(json_length)
    print(len(data_bytes))
# Out:
# 627

# %%
import numpy as np

# 创建一个示例 NumPy 向量
vector = np.array([123, 45, 6789, 10, 234]).reshape(-1,1)

# 指定输出文件
output_file = 'output.txt'

# 将元素写入txt文件，并右对齐
with open(output_file, 'w') as f:
    for element in vector:
        f.write(f"{str(element).rjust(10)}\n")  # 每个元素占10个字符的宽度，右对齐

print(f"数据已写入到 {output_file}")
# Out:
# 数据已写入到 output.txt

# %%
A="1234.5678"
print(A.split(".")[0][0:2])
# Out:
# 12
